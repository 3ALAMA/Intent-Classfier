# %%
import nltk
from nltk.stem.lancaster import LancasterStemmer
# word stemmer
stemmer = LancasterStemmer()

# %%
import pandas as pd
dataset = pd.read_csv("data.csv")

# %%
dataset
# Out:
#                                                   Data              intent  \
# 0                                          فاتحين امتى         information
# 1                                        عندكو اكل ايه                menu
# 2                                        في مينيم شارج              prices
# 3                                          في ديليفيري         information
# 4                                      ينفع احجز قبلها  Reservation system
# 5                                     هيبقي الساعة كام         information
# 6                             ممكن رقم الدليفرى بتاعكم         information
# 7                    لو عاوزه اجي احجز قبلها بيوم ينفع  Reservation system
# 8                                         عاوزه المنيو                menu
# 9                       نظام الحجز ايه فى المحل الجديد  Reservation system
# 10                 عايز نعرف هتبقا ماشيه ازاي في رمضان  Reservation system
# 11        نحجز ازاي عشان احنا من بعيد نجي علي امتي كدة  Reservation system
# 12   نظام الحجز في رمضان ازاي فيه تليفون ولا ايه ال...  Reservation system
# 13                               هتكونو شغلين في العيد         information
# 14   انا عايز احجز طربيزه واجي قبل الفطار بقليل ما ...  Reservation system
# 15   ممكن اعرف في حجز ولا اجي علي طول ولو في حجز بح...  Reservation system
# 16   يعنى لو عزنا نفطر بقي نيجى على طول ولا نحجز ون...  Reservation system
# 17                                           الرقم فين         information
# 18   ممكن إستفسار هوه العمل في رمضان لحد الساعة كام...         information
# 19    الفطار في رمضان محتاج حجز حضور ولا ينفع التليفون  Reservation system
# 20                                      ازاى يتم الحجز  Reservation system
# 21        كنت عايز اعرف احجز الاول ولا اجى وانا ونصيبى  Reservation system
# 22        هو حضرتك لو جيت الساعه 4 الاقي حجز ل 7 افراد  Reservation system
# 23                          اقدر احجز من خلال التليفون  Reservation system
# 24                                 هو فى مكان للركنة ؟         information
# 25                        بنعمل حجز ولا ايه نظام رمضان  Reservation system
# 26                     عنوان اى حضرتك واقرب محِطة مترو         information
# 27                                مفيش دليفري للمنصوره         information
# 28                             طيب هو بالحجز ولا ايه!؟  Reservation system
# 29   لو حبيت اجى والاولاد اجى من الساعه كام قبل الفطار         information
# ..                                                 ...                 ...
# 82                                     رقم الفون للحجز         information
# 83                             العرض في فرع مدينه نصر؟              offers
# 84                العرض ساعه الفطار بس ولا بعد الفطار؟              offers
# 85                  هل فيه خدمة توصيل الطلبات للمنازل؟         information
# 86                           العرض ساري في فرع الرحاب؟              offers
# 87                                  ايه هي منيو السحور                menu
# 88                             لازم حجز ولا نيجي عادي؟  Reservation system
# 89                             ممكن المنيو بتاعت رمضان                menu
# 90                       ممكن اعرف منيو رمضان بالاسعار                menu
# 91                       فيه ضريبة وخدمة كام في المية؟              prices
# 92                             هل بيتضاف خدمة وضريبة ؟              prices
# 93                                          ممكن عنوان         information
# 94                                        مكانكم فين ؟         information
# 95                                      فين فمدينة نصر         information
# 96                               عنوان فرع مدينه نصر ؟         information
# 97   طيب اوردر الدليفري عليه ضريبة 14% زي المطعم ول...              prices
# 98                   التوصيل لكوبري القبة بكام لز سمحت              prices
# 99                هو ممكن التوصيل للمرج الجديدة ولا لا         information
# 100  لو سمحت فيه توصيل مدينة الشروق طريق مصر الاسما...         information
# 101                                    ممكن صور المنيو                menu
# 102                    هو ممكن يجى المطريه عادى ولا لا         information
# 103  من فضلك هو الفروع كلها مفتوحه ولا الفرع الرئيس...         information
# 104    لو سمحت فى توصيل الى شبرا الخيمة من على الدائرى         information
# 105             فيه توصيل لاول الهرم من ناحية الجيزه ؟         information
# 106                        في فرع موجود في مصر الجديده         information
# 107                         لو سمحت نظام التيك اوي أيه         information
# 108                        ياترى فيه خدمه توصيل للرحاب         information
# 109                  لو في مطار امبابه فى توصيل والسعر         information
# 110                              ممكن التوصيل فى حلوان         information
# 111                               المطعم اشتغل ولا لسه         information
#
#                                  Entity
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                 [(5,17,رقم تليفون)]\n
# 7                                   NaN
# 8                       [(6,13,المنيو)]
# 9                                   NaN
# 10                        [(30,35,وقت)]
# 11                                  NaN
# 12   [(29,35,رقم تليفون),(14,19,وقت)]\n
# 13                        [(16,21,وقت)]
# 14                        [(30,36,وقت)]
# 15                                  NaN
# 16                                  NaN
# 17                   [(0,5,رقم تليفون)]
# 18                        [(26,31,وقت)]
# 19                        [(10,15,وقت)]
# 20                                  NaN
# 21                                  NaN
# 22         [(37,44,الكمية),(16,24,وقت)]
# 23                 [(18,26,رقم تليفون)]
# 24                                  NaN
# 25                        [(23,28,وقت)]
# 26                       [(21,30,مكان)]
# 27                       [(14,20,مكان)]
# 28                                  NaN
# 29                        [(43,49,وقت)]
# ..                                  ...
# 82                                  NaN
# 83                                  NaN
# 84                                  NaN
# 85                                  NaN
# 86                                  NaN
# 87                                  NaN
# 88                                  NaN
# 89                                  NaN
# 90                                  NaN
# 91                                  NaN
# 92                                  NaN
# 93                                  NaN
# 94                                  NaN
# 95                                  NaN
# 96                                  NaN
# 97                                  NaN
# 98                                  NaN
# 99                                  NaN
# 100                                 NaN
# 101                                 NaN
# 102                                 NaN
# 103                                 NaN
# 104                                 NaN
# 105                                 NaN
# 106                                 NaN
# 107                                 NaN
# 108                                 NaN
# 109                                 NaN
# 110                                 NaN
# 111                                 NaN
#
# [112 rows x 3 columns]

# %%
del dataset['Entity']

# %%
dataset
# Out:
#                                                   Data              intent
# 0                                          فاتحين امتى         information
# 1                                        عندكو اكل ايه                menu
# 2                                        في مينيم شارج              prices
# 3                                          في ديليفيري         information
# 4                                      ينفع احجز قبلها  Reservation system
# 5                                     هيبقي الساعة كام         information
# 6                             ممكن رقم الدليفرى بتاعكم         information
# 7                    لو عاوزه اجي احجز قبلها بيوم ينفع  Reservation system
# 8                                         عاوزه المنيو                menu
# 9                       نظام الحجز ايه فى المحل الجديد  Reservation system
# 10                 عايز نعرف هتبقا ماشيه ازاي في رمضان  Reservation system
# 11        نحجز ازاي عشان احنا من بعيد نجي علي امتي كدة  Reservation system
# 12   نظام الحجز في رمضان ازاي فيه تليفون ولا ايه ال...  Reservation system
# 13                               هتكونو شغلين في العيد         information
# 14   انا عايز احجز طربيزه واجي قبل الفطار بقليل ما ...  Reservation system
# 15   ممكن اعرف في حجز ولا اجي علي طول ولو في حجز بح...  Reservation system
# 16   يعنى لو عزنا نفطر بقي نيجى على طول ولا نحجز ون...  Reservation system
# 17                                           الرقم فين         information
# 18   ممكن إستفسار هوه العمل في رمضان لحد الساعة كام...         information
# 19    الفطار في رمضان محتاج حجز حضور ولا ينفع التليفون  Reservation system
# 20                                      ازاى يتم الحجز  Reservation system
# 21        كنت عايز اعرف احجز الاول ولا اجى وانا ونصيبى  Reservation system
# 22        هو حضرتك لو جيت الساعه 4 الاقي حجز ل 7 افراد  Reservation system
# 23                          اقدر احجز من خلال التليفون  Reservation system
# 24                                 هو فى مكان للركنة ؟         information
# 25                        بنعمل حجز ولا ايه نظام رمضان  Reservation system
# 26                     عنوان اى حضرتك واقرب محِطة مترو         information
# 27                                مفيش دليفري للمنصوره         information
# 28                             طيب هو بالحجز ولا ايه!؟  Reservation system
# 29   لو حبيت اجى والاولاد اجى من الساعه كام قبل الفطار         information
# ..                                                 ...                 ...
# 82                                     رقم الفون للحجز         information
# 83                             العرض في فرع مدينه نصر؟              offers
# 84                العرض ساعه الفطار بس ولا بعد الفطار؟              offers
# 85                  هل فيه خدمة توصيل الطلبات للمنازل؟         information
# 86                           العرض ساري في فرع الرحاب؟              offers
# 87                                  ايه هي منيو السحور                menu
# 88                             لازم حجز ولا نيجي عادي؟  Reservation system
# 89                             ممكن المنيو بتاعت رمضان                menu
# 90                       ممكن اعرف منيو رمضان بالاسعار                menu
# 91                       فيه ضريبة وخدمة كام في المية؟              prices
# 92                             هل بيتضاف خدمة وضريبة ؟              prices
# 93                                          ممكن عنوان         information
# 94                                        مكانكم فين ؟         information
# 95                                      فين فمدينة نصر         information
# 96                               عنوان فرع مدينه نصر ؟         information
# 97   طيب اوردر الدليفري عليه ضريبة 14% زي المطعم ول...              prices
# 98                   التوصيل لكوبري القبة بكام لز سمحت              prices
# 99                هو ممكن التوصيل للمرج الجديدة ولا لا         information
# 100  لو سمحت فيه توصيل مدينة الشروق طريق مصر الاسما...         information
# 101                                    ممكن صور المنيو                menu
# 102                    هو ممكن يجى المطريه عادى ولا لا         information
# 103  من فضلك هو الفروع كلها مفتوحه ولا الفرع الرئيس...         information
# 104    لو سمحت فى توصيل الى شبرا الخيمة من على الدائرى         information
# 105             فيه توصيل لاول الهرم من ناحية الجيزه ؟         information
# 106                        في فرع موجود في مصر الجديده         information
# 107                         لو سمحت نظام التيك اوي أيه         information
# 108                        ياترى فيه خدمه توصيل للرحاب         information
# 109                  لو في مطار امبابه فى توصيل والسعر         information
# 110                              ممكن التوصيل فى حلوان         information
# 111                               المطعم اشتغل ولا لسه         information
#
# [112 rows x 2 columns]

# %%
dataset.to_csv('dataset.csv')

# %%
training_data = []
for intent in dataset['intent'].unique():
    for text in dataset[dataset['intent']==intent]["Data"]:
        training_data.append({"class":intent,"sentence":text})

# %%
training_data
# Out:
# [{'class': 'information', 'sentence': 'فاتحين امتى'},
#  {'class': 'information', 'sentence': 'في ديليفيري'},
#  {'class': 'information', 'sentence': 'هيبقي الساعة كام'},
#  {'class': 'information', 'sentence': 'ممكن رقم الدليفرى بتاعكم'},
#  {'class': 'information', 'sentence': 'هتكونو شغلين في العيد'},
#  {'class': 'information', 'sentence': 'الرقم فين'},
#  {'class': 'information',
#   'sentence': 'ممكن إستفسار هوه العمل في رمضان لحد الساعة كام ؟ ؟'},
#  {'class': 'information', 'sentence': 'هو فى مكان للركنة ؟'},
#  {'class': 'information', 'sentence': 'عنوان اى حضرتك واقرب محِطة مترو'},
#  {'class': 'information', 'sentence': 'مفيش دليفري للمنصوره'},
#  {'class': 'information',
#   'sentence': 'لو حبيت اجى والاولاد اجى من الساعه كام قبل الفطار'},
#  {'class': 'information', 'sentence': 'هو انت قافل من اول رمضان'},
#  {'class': 'information', 'sentence': 'في دليفري لمدينة نصر'},
#  {'class': 'information', 'sentence': 'المكان فين لو سمحت'},
#  {'class': 'information',
#   'sentence': 'الدليفري هيشتغل ولو هيشتغل هتستقبل الطلبات من الساعه كام'},
#  {'class': 'information', 'sentence': 'المطعم بيفتح الساعه كام لو سمحت'},
#  {'class': 'information', 'sentence': 'ده انهى فرع لو سمحت'},
#  {'class': 'information', 'sentence': 'الدليفرى حيشتغل امتى'},
#  {'class': 'information', 'sentence': 'تيك اوي هيكون شغال يوم الخميس'},
#  {'class': 'information', 'sentence': 'لو عايز اعمل اوردر مفيش رقم تلفون'},
#  {'class': 'information', 'sentence': 'الحجز من الساعة كام'},
#  {'class': 'information', 'sentence': 'في دليفري لمدينتي'},
#  {'class': 'information',
#   'sentence': 'طب لو سمحتوا في ديلفري ﻻول السلام اردر كبير شويه لعزومه'},
#  {'class': 'information', 'sentence': 'هل الدليفرى بيوصل عين شمس'},
#  {'class': 'information', 'sentence': 'انتوا شغالين بكره'},
#  {'class': 'information', 'sentence': 'ممكن رقم تليفون للتواصل'},
#  {'class': 'information', 'sentence': 'من فضلك هتكونو شغالين أيام العيد'},
#  {'class': 'information', 'sentence': 'ممكن العنوان بالظبط لو سمحت'},
#  {'class': 'information', 'sentence': 'شغالين لحد كام بالليل'},
#  {'class': 'information', 'sentence': 'ممكن اعرف رقم فرع عباس العقاد'},
#  {'class': 'information',
#   'sentence': 'لو سمحت اقدر اعرف ممكن توصيل طلبات فى فيصل الجيزة'},
#  {'class': 'information',
#   'sentence': 'ممكن عنوان فرع مصر الجديدة ورقم التليفون'},
#  {'class': 'information', 'sentence': 'فرع النادي الاهلي مفتوح و الا لأ'},
#  {'class': 'information',
#   'sentence': 'لو سمحتوا يتوصلوا لثكنات المعادي ولا لا'},
#  {'class': 'information', 'sentence': 'هل يوجد توصيل للتجمع الأول'},
#  {'class': 'information',
#   'sentence': 'ممكن اعرف ليكم فرع فى المهندسين ولا لا'},
#  {'class': 'information', 'sentence': 'الرقم مش شغال'},
#  {'class': 'information', 'sentence': 'فروعكوا فين'},
#  {'class': 'information', 'sentence': 'في فروع ف المعادي'},
#  {'class': 'information', 'sentence': 'الفروع لو سمحتو'},
#  {'class': 'information', 'sentence': 'رقم الفون للحجز'},
#  {'class': 'information', 'sentence': 'هل فيه خدمة توصيل الطلبات للمنازل؟'},
#  {'class': 'information', 'sentence': 'ممكن عنوان'},
#  {'class': 'information', 'sentence': 'مكانكم فين ؟'},
#  {'class': 'information', 'sentence': 'فين فمدينة نصر'},
#  {'class': 'information', 'sentence': 'عنوان فرع مدينه نصر ؟'},
#  {'class': 'information', 'sentence': 'هو ممكن التوصيل للمرج الجديدة ولا لا'},
#  {'class': 'information',
#   'sentence': 'لو سمحت فيه توصيل مدينة الشروق طريق مصر الاسماعيليه'},
#  {'class': 'information', 'sentence': 'هو ممكن يجى المطريه عادى ولا لا'},
#  {'class': 'information',
#   'sentence': 'من فضلك هو الفروع كلها مفتوحه ولا الفرع الرئيسي مغلق'},
#  {'class': 'information',
#   'sentence': 'لو سمحت فى توصيل الى شبرا الخيمة من على الدائرى'},
#  {'class': 'information',
#   'sentence': 'فيه توصيل لاول الهرم من ناحية الجيزه ؟'},
#  {'class': 'information', 'sentence': 'في فرع موجود في مصر الجديده'},
#  {'class': 'information', 'sentence': 'لو سمحت نظام التيك اوي أيه'},
#  {'class': 'information', 'sentence': 'ياترى فيه خدمه توصيل للرحاب'},
#  {'class': 'information', 'sentence': 'لو في مطار امبابه فى توصيل والسعر'},
#  {'class': 'information', 'sentence': 'ممكن التوصيل فى حلوان'},
#  {'class': 'information', 'sentence': 'المطعم اشتغل ولا لسه'},
#  {'class': 'menu', 'sentence': 'عندكو اكل ايه'},
#  {'class': 'menu', 'sentence': 'عاوزه المنيو'},
#  {'class': 'menu', 'sentence': 'ممكن المنيو الجديدة'},
#  {'class': 'menu', 'sentence': 'عاوزين المنيو !!؟'},
#  {'class': 'menu', 'sentence': 'المنيو من فضلكم'},
#  {'class': 'menu', 'sentence': 'ممكن قايمه الاسعار'},
#  {'class': 'menu', 'sentence': 'هو في منيو جديد لرمضان ولا زي ما هو'},
#  {'class': 'menu', 'sentence': 'في حاجه جديده'},
#  {'class': 'menu', 'sentence': 'ايه هي منيو السحور'},
#  {'class': 'menu', 'sentence': 'ممكن المنيو بتاعت رمضان'},
#  {'class': 'menu', 'sentence': 'ممكن اعرف منيو رمضان بالاسعار'},
#  {'class': 'menu', 'sentence': 'ممكن صور المنيو'},
#  {'class': 'prices', 'sentence': 'في مينيم شارج'},
#  {'class': 'prices',
#   'sentence': 'هو في ضريبة قيمة مضافة و12%,خدمة ع الاكل ولا ايه النظام'},
#  {'class': 'prices', 'sentence': 'الأسعار عندكم شاملة الضريبة والخدمة'},
#  {'class': 'prices', 'sentence': 'سعر الوجبه دى كام بقي'},
#  {'class': 'prices', 'sentence': 'السعر كام دلوقتي'},
#  {'class': 'prices', 'sentence': 'بكام الشطوره'},
#  {'class': 'prices', 'sentence': 'فيه ضريبة وخدمة كام في المية؟'},
#  {'class': 'prices', 'sentence': 'هل بيتضاف خدمة وضريبة ؟'},
#  {'class': 'prices',
#   'sentence': 'طيب اوردر الدليفري عليه ضريبة 14% زي المطعم ولا ايه النظام'},
#  {'class': 'prices', 'sentence': 'التوصيل لكوبري القبة بكام لز سمحت'},
#  {'class': 'Reservation system', 'sentence': 'ينفع احجز قبلها'},
#  {'class': 'Reservation system',
#   'sentence': 'لو عاوزه اجي احجز قبلها بيوم ينفع'},
#  {'class': 'Reservation system', 'sentence': 'نظام الحجز ايه فى المحل الجديد'},
#  {'class': 'Reservation system',
#   'sentence': 'عايز نعرف هتبقا ماشيه ازاي في رمضان'},
#  {'class': 'Reservation system',
#   'sentence': 'نحجز ازاي عشان احنا من بعيد نجي علي امتي كدة'},
#  {'class': 'Reservation system',
#   'sentence': 'نظام الحجز في رمضان ازاي فيه تليفون ولا ايه النظام'},
#  {'class': 'Reservation system',
#   'sentence': 'انا عايز احجز طربيزه واجي قبل الفطار بقليل ما هو السبيل'},
#  {'class': 'Reservation system',
#   'sentence': 'ممكن اعرف في حجز ولا اجي علي طول ولو في حجز بحجز ازاي'},
#  {'class': 'Reservation system',
#   'sentence': 'يعنى لو عزنا نفطر بقي نيجى على طول ولا نحجز ونيجى الساعه كام'},
#  {'class': 'Reservation system',
#   'sentence': 'الفطار في رمضان محتاج حجز حضور ولا ينفع التليفون'},
#  {'class': 'Reservation system', 'sentence': 'ازاى يتم الحجز'},
#  {'class': 'Reservation system',
#   'sentence': 'كنت عايز اعرف احجز الاول ولا اجى وانا ونصيبى'},
#  {'class': 'Reservation system',
#   'sentence': 'هو حضرتك لو جيت الساعه 4 الاقي حجز ل 7 افراد'},
#  {'class': 'Reservation system', 'sentence': 'اقدر احجز من خلال التليفون'},
#  {'class': 'Reservation system', 'sentence': 'بنعمل حجز ولا ايه نظام رمضان'},
#  {'class': 'Reservation system', 'sentence': 'طيب هو بالحجز ولا ايه!؟'},
#  {'class': 'Reservation system', 'sentence': 'لو سمحت الحجز هيبقى ازاى'},
#  {'class': 'Reservation system',
#   'sentence': 'يعني لو جيت علي الساعه 5 هلحق ولا اجي قبل كده'},
#  {'class': 'Reservation system', 'sentence': 'الحجز ازاي طيب'},
#  {'class': 'Reservation system',
#   'sentence': ' عايز احجز انا وصحابي المقربين يوم الخميس القادم اذاي '},
#  {'class': 'Reservation system',
#   'sentence': 'هو مممكن فرد واحد يحجز لمجمموعه كامله لو جه بدري ولا لازم كل الناس يكونو موجودين من بدري ؟'},
#  {'class': 'Reservation system',
#   'sentence': 'والمفروض اطلب الاوردر قبلها باد اية'},
#  {'class': 'Reservation system',
#   'sentence': 'ايه انسب وقت اجي فيه بعد الفطار'},
#  {'class': 'Reservation system',
#   'sentence': 'انا عوزه احجز بس انا بعيده ومش هادر اجى الفرع اعمل ايه'},
#  {'class': 'Reservation system',
#   'sentence': 'بحاول اتصل عشان احجز لبكره فطار ومش عارفه اوصل'},
#  {'class': 'Reservation system',
#   'sentence': 'طب ممكن رقم الحجز عايز احجز لخمس أفراد'},
#  {'class': 'Reservation system', 'sentence': 'لازم حجز ولا نيجي عادي؟'},
#  {'class': 'offers', 'sentence': 'طب بكرة مش فيري بمناسبة الافتتاح'},
#  {'class': 'offers', 'sentence': 'ممكن اعرف انتو عاملين أية عروض فى رمضان'},
#  {'class': 'offers', 'sentence': 'العرض في فرع مدينه نصر؟'},
#  {'class': 'offers', 'sentence': 'العرض ساعه الفطار بس ولا بعد الفطار؟'},
#  {'class': 'offers', 'sentence': 'العرض ساري في فرع الرحاب؟'}]

# %%
print ("%s sentences of training data" % len(training_data))
# Out:
# 112 sentences of training data

# %%
# capture unique stemmed words in the training corpus
corpus_words = {}
class_words = {}
# turn a list into a set (of unique items) and then a list again (this removes duplicates)
classes = list(set([a['class'] for a in training_data]))
for c in classes:
    # prepare a list of words within each class
    class_words[c] = []

# loop through each sentence in our training data
for data in training_data:
    # tokenize each sentence into words
    for word in nltk.word_tokenize(data['sentence']):
        # ignore a some things
        if word not in ["؟"]:
            # stem and lowercase each word
            stemmed_word = stemmer.stem(word.lower())
            # have we not seen this word already?
            if stemmed_word not in corpus_words:
                corpus_words[stemmed_word] = 1
            else:
                corpus_words[stemmed_word] += 1

            # add the word to our words in class list
            class_words[data['class']].extend([stemmed_word])

# we now have each stemmed word and the number of occurances of the word in our training corpus (the word's commonality)
print ("Corpus words and counts: %s \n" % corpus_words)
# also we have all words in each class
print ("Class words: %s" % class_words)
# Out:
# Corpus words and counts: {'فاتحين': 1, 'امتى': 2, 'في': 22, 'ديليفيري': 1, 'هيبقي': 1, 'الساعة': 3, 'كام': 11, 'ممكن': 20, 'رقم': 6, 'الدليفرى': 3, 'بتاعكم': 1, 'هتكونو': 2, 'شغلين': 1, 'العيد': 2, 'الرقم': 2, 'فين': 5, 'إستفسار': 1, 'هوه': 1, 'العمل': 1, 'رمضان': 9, 'لحد': 2, 'هو': 12, 'فى': 8, 'مكان': 1, 'للركنة': 1, 'عنوان': 4, 'اى': 1, 'حضرتك': 2, 'واقرب': 1, 'محِطة': 1, 'مترو': 1, 'مفيش': 2, 'دليفري': 3, 'للمنصوره': 1, 'لو': 20, 'حبيت': 1, 'اجى': 4, 'والاولاد': 1, 'من': 12, 'الساعه': 6, 'قبل': 3, 'الفطار': 5, 'انت': 1, 'قافل': 1, 'اول': 1, 'لمدينة': 1, 'نصر': 3, 'المكان': 1, 'سمحت': 10, 'الدليفري': 2, 'هيشتغل': 2, 'ولو': 2, 'هتستقبل': 1, 'الطلبات': 2, 'المطعم': 3, 'بيفتح': 1, 'ده': 1, 'انهى': 1, 'فرع': 9, 'حيشتغل': 1, 'تيك': 1, 'اوي': 2, 'هيكون': 1, 'شغال': 2, 'يوم': 2, 'الخميس': 2, 'عايز': 6, 'اعمل': 2, 'اوردر': 2, 'تلفون': 1, 'الحجز': 7, 'لمدينتي': 1, 'طب': 3, 'سمحتوا': 2, 'ديلفري': 1, 'ﻻول': 1, 'السلام': 1, 'اردر': 1, 'كبير': 1, 'شويه': 1, 'لعزومه': 1, 'هل': 4, 'بيوصل': 1, 'عين': 1, 'شمس': 1, 'انتوا': 1, 'شغالين': 3, 'بكره': 1, 'تليفون': 2, 'للتواصل': 1, 'فضلك': 2, 'أيام': 1, 'العنوان': 1, 'بالظبط': 1, 'بالليل': 1, 'اعرف': 7, 'عباس': 1, 'العقاد': 1, 'اقدر': 2, 'توصيل': 8, 'طلبات': 1, 'فيصل': 1, 'الجيزة': 1, 'مصر': 3, 'الجديدة': 3, 'ورقم': 1, 'التليفون': 3, 'النادي': 1, 'الاهلي': 1, 'مفتوح': 1, 'و': 1, 'الا': 1, 'لأ': 1, 'يتوصلوا': 1, 'لثكنات': 1, 'المعادي': 2, 'ولا': 20, 'لا': 4, 'يوجد': 1, 'للتجمع': 1, 'الأول': 1, 'ليكم': 1, 'المهندسين': 1, 'مش': 2, 'فروعكوا': 1, 'فروع': 1, 'ف': 1, 'الفروع': 2, 'سمحتو': 1, 'الفون': 1, 'للحجز': 1, 'فيه': 7, 'خدمة': 3, 'للمنازل؟': 1, 'مكانكم': 1, 'فمدينة': 1, 'مدينه': 2, 'التوصيل': 3, 'للمرج': 1, 'مدينة': 1, 'الشروق': 1, 'طريق': 1, 'الاسماعيليه': 1, 'يجى': 1, 'المطريه': 1, 'عادى': 1, 'كلها': 1, 'مفتوحه': 1, 'الفرع': 2, 'الرئيسي': 1, 'مغلق': 1, 'الى': 1, 'شبرا': 1, 'الخيمة': 1, 'على': 2, 'الدائرى': 1, 'لاول': 1, 'الهرم': 1, 'ناحية': 1, 'الجيزه': 1, 'موجود': 1, 'الجديده': 1, 'نظام': 4, 'التيك': 1, 'أيه': 1, 'ياترى': 1, 'خدمه': 1, 'للرحاب': 1, 'مطار': 1, 'امبابه': 1, 'والسعر': 1, 'حلوان': 1, 'اشتغل': 1, 'لسه': 1, 'عندكو': 1, 'اكل': 1, 'ايه': 10, 'عاوزه': 2, 'المنيو': 6, 'عاوزين': 1, '!': 3, 'فضلكم': 1, 'قايمه': 1, 'الاسعار': 1, 'منيو': 3, 'جديد': 1, 'لرمضان': 1, 'زي': 2, 'ما': 2, 'حاجه': 1, 'جديده': 1, 'هي': 1, 'السحور': 1, 'بتاعت': 1, 'بالاسعار': 1, 'صور': 1, 'مينيم': 1, 'شارج': 1, 'ضريبة': 3, 'قيمة': 1, 'مضافة': 1, 'و12': 1, '%': 2, ',': 1, 'ع': 1, 'الاكل': 1, 'النظام': 3, 'الأسعار': 1, 'عندكم': 1, 'شاملة': 1, 'الضريبة': 1, 'والخدمة': 1, 'سعر': 1, 'الوجبه': 1, 'دى': 1, 'بقي': 2, 'السعر': 1, 'دلوقتي': 1, 'بكام': 2, 'الشطوره': 1, 'وخدمة': 1, 'المية؟': 1, 'بيتضاف': 1, 'وضريبة': 1, 'طيب': 3, 'عليه': 1, '14': 1, 'لكوبري': 1, 'القبة': 1, 'لز': 1, 'ينفع': 3, 'احجز': 9, 'قبلها': 3, 'اجي': 4, 'بيوم': 1, 'المحل': 1, 'الجديد': 1, 'نعرف': 1, 'هتبقا': 1, 'ماشيه': 1, 'ازاي': 5, 'نحجز': 2, 'عشان': 2, 'احنا': 1, 'بعيد': 1, 'نجي': 1, 'علي': 3, 'امتي': 1, 'كدة': 1, 'انا': 4, 'طربيزه': 1, 'واجي': 1, 'بقليل': 1, 'السبيل': 1, 'حجز': 6, 'طول': 2, 'بحجز': 1, 'يعنى': 1, 'عزنا': 1, 'نفطر': 1, 'نيجى': 1, 'ونيجى': 1, 'محتاج': 1, 'حضور': 1, 'ازاى': 2, 'يتم': 1, 'كنت': 1, 'الاول': 1, 'وانا': 1, 'ونصيبى': 1, 'جيت': 2, '4': 1, 'الاقي': 1, 'ل': 1, '7': 1, 'افراد': 1, 'خلال': 1, 'بنعمل': 1, 'بالحجز': 1, 'هيبقى': 1, 'يعني': 1, '5': 1, 'هلحق': 1, 'كده': 1, 'وصحابي': 1, 'المقربين': 1, 'القادم': 1, 'اذاي': 1, 'مممكن': 1, 'فرد': 1, 'واحد': 1, 'يحجز': 1, 'لمجمموعه': 1, 'كامله': 1, 'جه': 1, 'بدري': 2, 'لازم': 2, 'كل': 1, 'الناس': 1, 'يكونو': 1, 'موجودين': 1, 'والمفروض': 1, 'اطلب': 1, 'الاوردر': 1, 'باد': 1, 'اية': 1, 'انسب': 1, 'وقت': 1, 'بعد': 2, 'عوزه': 1, 'بس': 2, 'بعيده': 1, 'ومش': 2, 'هادر': 1, 'بحاول': 1, 'اتصل': 1, 'لبكره': 1, 'فطار': 1, 'عارفه': 1, 'اوصل': 1, 'لخمس': 1, 'أفراد': 1, 'نيجي': 1, 'عادي؟': 1, 'بكرة': 1, 'فيري': 1, 'بمناسبة': 1, 'الافتتاح': 1, 'انتو': 1, 'عاملين': 1, 'أية': 1, 'عروض': 1, 'العرض': 3, 'نصر؟': 1, 'ساعه': 1, 'الفطار؟': 1, 'ساري': 1, 'الرحاب؟': 1}
#
# Class words: {'Reservation system': ['ينفع', 'احجز', 'قبلها', 'لو', 'عاوزه', 'اجي', 'احجز', 'قبلها', 'بيوم', 'ينفع', 'نظام', 'الحجز', 'ايه', 'فى', 'المحل', 'الجديد', 'عايز', 'نعرف', 'هتبقا', 'ماشيه', 'ازاي', 'في', 'رمضان', 'نحجز', 'ازاي', 'عشان', 'احنا', 'من', 'بعيد', 'نجي', 'علي', 'امتي', 'كدة', 'نظام', 'الحجز', 'في', 'رمضان', 'ازاي', 'فيه', 'تليفون', 'ولا', 'ايه', 'النظام', 'انا', 'عايز', 'احجز', 'طربيزه', 'واجي', 'قبل', 'الفطار', 'بقليل', 'ما', 'هو', 'السبيل', 'ممكن', 'اعرف', 'في', 'حجز', 'ولا', 'اجي', 'علي', 'طول', 'ولو', 'في', 'حجز', 'بحجز', 'ازاي', 'يعنى', 'لو', 'عزنا', 'نفطر', 'بقي', 'نيجى', 'على', 'طول', 'ولا', 'نحجز', 'ونيجى', 'الساعه', 'كام', 'الفطار', 'في', 'رمضان', 'محتاج', 'حجز', 'حضور', 'ولا', 'ينفع', 'التليفون', 'ازاى', 'يتم', 'الحجز', 'كنت', 'عايز', 'اعرف', 'احجز', 'الاول', 'ولا', 'اجى', 'وانا', 'ونصيبى', 'هو', 'حضرتك', 'لو', 'جيت', 'الساعه', '4', 'الاقي', 'حجز', 'ل', '7', 'افراد', 'اقدر', 'احجز', 'من', 'خلال', 'التليفون', 'بنعمل', 'حجز', 'ولا', 'ايه', 'نظام', 'رمضان', 'طيب', 'هو', 'بالحجز', 'ولا', 'ايه', '!', 'لو', 'سمحت', 'الحجز', 'هيبقى', 'ازاى', 'يعني', 'لو', 'جيت', 'علي', 'الساعه', '5', 'هلحق', 'ولا', 'اجي', 'قبل', 'كده', 'الحجز', 'ازاي', 'طيب', 'عايز', 'احجز', 'انا', 'وصحابي', 'المقربين', 'يوم', 'الخميس', 'القادم', 'اذاي', 'هو', 'مممكن', 'فرد', 'واحد', 'يحجز', 'لمجمموعه', 'كامله', 'لو', 'جه', 'بدري', 'ولا', 'لازم', 'كل', 'الناس', 'يكونو', 'موجودين', 'من', 'بدري', 'والمفروض', 'اطلب', 'الاوردر', 'قبلها', 'باد', 'اية', 'ايه', 'انسب', 'وقت', 'اجي', 'فيه', 'بعد', 'الفطار', 'انا', 'عوزه', 'احجز', 'بس', 'انا', 'بعيده', 'ومش', 'هادر', 'اجى', 'الفرع', 'اعمل', 'ايه', 'بحاول', 'اتصل', 'عشان', 'احجز', 'لبكره', 'فطار', 'ومش', 'عارفه', 'اوصل', 'طب', 'ممكن', 'رقم', 'الحجز', 'عايز', 'احجز', 'لخمس', 'أفراد', 'لازم', 'حجز', 'ولا', 'نيجي', 'عادي؟'], 'prices': ['في', 'مينيم', 'شارج', 'هو', 'في', 'ضريبة', 'قيمة', 'مضافة', 'و12', '%', ',', 'خدمة', 'ع', 'الاكل', 'ولا', 'ايه', 'النظام', 'الأسعار', 'عندكم', 'شاملة', 'الضريبة', 'والخدمة', 'سعر', 'الوجبه', 'دى', 'كام', 'بقي', 'السعر', 'كام', 'دلوقتي', 'بكام', 'الشطوره', 'فيه', 'ضريبة', 'وخدمة', 'كام', 'في', 'المية؟', 'هل', 'بيتضاف', 'خدمة', 'وضريبة', 'طيب', 'اوردر', 'الدليفري', 'عليه', 'ضريبة', '14', '%', 'زي', 'المطعم', 'ولا', 'ايه', 'النظام', 'التوصيل', 'لكوبري', 'القبة', 'بكام', 'لز', 'سمحت'], 'offers': ['طب', 'بكرة', 'مش', 'فيري', 'بمناسبة', 'الافتتاح', 'ممكن', 'اعرف', 'انتو', 'عاملين', 'أية', 'عروض', 'فى', 'رمضان', 'العرض', 'في', 'فرع', 'مدينه', 'نصر؟', 'العرض', 'ساعه', 'الفطار', 'بس', 'ولا', 'بعد', 'الفطار؟', 'العرض', 'ساري', 'في', 'فرع', 'الرحاب؟'], 'menu': ['عندكو', 'اكل', 'ايه', 'عاوزه', 'المنيو', 'ممكن', 'المنيو', 'الجديدة', 'عاوزين', 'المنيو', '!', '!', 'المنيو', 'من', 'فضلكم', 'ممكن', 'قايمه', 'الاسعار', 'هو', 'في', 'منيو', 'جديد', 'لرمضان', 'ولا', 'زي', 'ما', 'هو', 'في', 'حاجه', 'جديده', 'ايه', 'هي', 'منيو', 'السحور', 'ممكن', 'المنيو', 'بتاعت', 'رمضان', 'ممكن', 'اعرف', 'منيو', 'رمضان', 'بالاسعار', 'ممكن', 'صور', 'المنيو'], 'information': ['فاتحين', 'امتى', 'في', 'ديليفيري', 'هيبقي', 'الساعة', 'كام', 'ممكن', 'رقم', 'الدليفرى', 'بتاعكم', 'هتكونو', 'شغلين', 'في', 'العيد', 'الرقم', 'فين', 'ممكن', 'إستفسار', 'هوه', 'العمل', 'في', 'رمضان', 'لحد', 'الساعة', 'كام', 'هو', 'فى', 'مكان', 'للركنة', 'عنوان', 'اى', 'حضرتك', 'واقرب', 'محِطة', 'مترو', 'مفيش', 'دليفري', 'للمنصوره', 'لو', 'حبيت', 'اجى', 'والاولاد', 'اجى', 'من', 'الساعه', 'كام', 'قبل', 'الفطار', 'هو', 'انت', 'قافل', 'من', 'اول', 'رمضان', 'في', 'دليفري', 'لمدينة', 'نصر', 'المكان', 'فين', 'لو', 'سمحت', 'الدليفري', 'هيشتغل', 'ولو', 'هيشتغل', 'هتستقبل', 'الطلبات', 'من', 'الساعه', 'كام', 'المطعم', 'بيفتح', 'الساعه', 'كام', 'لو', 'سمحت', 'ده', 'انهى', 'فرع', 'لو', 'سمحت', 'الدليفرى', 'حيشتغل', 'امتى', 'تيك', 'اوي', 'هيكون', 'شغال', 'يوم', 'الخميس', 'لو', 'عايز', 'اعمل', 'اوردر', 'مفيش', 'رقم', 'تلفون', 'الحجز', 'من', 'الساعة', 'كام', 'في', 'دليفري', 'لمدينتي', 'طب', 'لو', 'سمحتوا', 'في', 'ديلفري', 'ﻻول', 'السلام', 'اردر', 'كبير', 'شويه', 'لعزومه', 'هل', 'الدليفرى', 'بيوصل', 'عين', 'شمس', 'انتوا', 'شغالين', 'بكره', 'ممكن', 'رقم ...

# %%
import numpy as np
# calculate a score for a given class taking into account word commonality
def calculate_class_score(sentence, class_name, show_details=True):
    score = 0
    # tokenize each word in our new sentence
    for word in nltk.word_tokenize(sentence):
        # check to see if the stem of the word is in any of our classes
        if stemmer.stem(word.lower()) in class_words[class_name]:
            # treat each word with relative weight
            score += (1 /corpus_words[stemmer.stem(word.lower())])*(1/class_words[class_name].count(stemmer.stem(word.lower())))

            if show_details:
                print (" match: %s (%s) * (%s)" % (stemmer.stem(word.lower()),
                                                   1 / corpus_words[stemmer.stem(word.lower())],
                                                   1/class_words[class_name].count(stemmer.stem(word.lower()))))
    return score

# %%
class_words['information'].count('لو')
# Out:
# 14

# %%
# we can now calculate a score for a new sentence
sentence = "ممكن اعرف المنيو ؟"
def trace(sentence):
    # now we can find the class with the highest score
    for c in class_words.keys():
        print ("Class: %s  Score: %s \n" % (c, calculate_class_score(sentence, c)))

# %%
trace(sentence)
# Out:
#  match: ممكن (0.05) * (0.5)
#  match: اعرف (0.14285714285714285) * (0.5)
# Class: Reservation system  Score: 0.09642857142857142
#
# Class: prices  Score: 0
#
#  match: ممكن (0.05) * (1.0)
#  match: اعرف (0.14285714285714285) * (1.0)
# Class: offers  Score: 0.19285714285714284
#
#  match: ممكن (0.05) * (0.2)
#  match: اعرف (0.14285714285714285) * (1.0)
#  match: المنيو (0.16666666666666666) * (0.16666666666666666)
# Class: menu  Score: 0.18063492063492065
#
#  match: ممكن (0.05) * (0.08333333333333333)
#  match: اعرف (0.14285714285714285) * (0.3333333333333333)
# Class: information  Score: 0.05178571428571428

# %%
def classify(sentence):
    high_class = None
    high_score = 0
    # loop through our classes
    for c in class_words.keys():
        # calculate score of sentence for each class
        score = calculate_class_score(sentence, c, show_details=False)
        # keep track of highest score
        if score > high_score:
            high_class = c
            high_score = score

    return high_class, high_score

# %%
classify("عندكوا اكل ايه")
# Out:
# ('menu', 1.2)

# %%
classify("ممكن اعرف فاتحين امتى")
# Out:
# ('information', 3.0285714285714285)

# %%
classify("المكان فين بالظبط")
# Out:
# ('information', 3.0)

# %%
classify("الأسعار ايه نظامها")
# Out:
# ('prices', 1.2)

# %%
classify("لو عايز حجز يبقى قبلها بقد ايه")
# Out:
# ('Reservation system', 3.7333333333333334)

# %%
classify("الدليفرى ايه نظامه")
# Out:
# ('information', 1.0)

# %%
trace("فى توصيل للجيزة")
# Out:
#  match: فى (0.125) * (1)
# Class: Reservation system  Score: 0.125
#
# Class: prices  Score: 0
#
#  match: فى (0.125) * (1)
# Class: offers  Score: 0.125
#
# Class: menu  Score: 0
#
#  match: فى (0.125) * (6)
#  match: توصيل (0.125) * (8)
# Class: information  Score: 1.75

# %%
classify("الاسعار شاملة الضريبة ولا لا")
# Out:
# ('prices', 2.1)

# %%
classify("عندكوا اكل ايه جديد")
# Out:
# ('menu', 2.2)

# %%
classify("ممكن قايمة الاسعار")
# Out:
# ('menu', 1.25)

# %%
classify("ممكن منيو رمضان")
# Out:
# ('menu', 1.4722222222222223)

# %%
trace("المنيو الجديدة لو سمحت")
# Out:
#  match: لو (0.05) * (6)
#  match: سمحت (0.1) * (1)
# Class: Reservation system  Score: 0.4
#
#  match: سمحت (0.1) * (1)
# Class: prices  Score: 0.1
#
# Class: offers  Score: 0
#
#  match: المنيو (0.16666666666666666) * (6)
#  match: الجديدة (0.3333333333333333) * (1)
# Class: menu  Score: 1.3333333333333333
#
#  match: الجديدة (0.3333333333333333) * (2)
#  match: لو (0.05) * (14)
#  match: سمحت (0.1) * (8)
# Class: information  Score: 2.166666666666667

# %%
classify("اسعار رمضان ايه")
# Out:
# ('offers', 0.1111111111111111)

# %%
classify("فى ايه جديد فى رمضان")
# Out:
# ('menu', 1.1055555555555556)

# %%
classify("احجز ازاى")
# Out:
# ('Reservation system', 0.2623456790123457)

# %%
classify("ممكن رقم التليفون")
# Out:
# ('information', 0.3708333333333333)

# %%
classify("فى عروض جديدة؟")
# Out:
# ('offers', 1.125)
